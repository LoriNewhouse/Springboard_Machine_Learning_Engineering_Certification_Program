# %% [markdown]
# # Chapter 2: Manipulating Data

# %% [markdown]
# ### refresh data and check
# next cell makes all tables in `u23_2_3` available in current session

# %%
# %sql
use u23_2_3;
show tables;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>u23_2_3</td><td>airports</td><td>false</td></tr><tr><td>u23_2_3</td><td>flights_larger</td><td>false</td></tr><tr><td>u23_2_3</td><td>flights_small</td><td>false</td></tr><tr><td>u23_2_3</td><td>planes</td><td>false</td></tr></tbody></table></div>

# %%
print(spark.catalog.listTables())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">[Table(name=&#39;airports&#39;, database=&#39;u23_2_3&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False), Table(name=&#39;flights_larger&#39;, database=&#39;u23_2_3&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False), Table(name=&#39;flights_small&#39;, database=&#39;u23_2_3&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False), Table(name=&#39;planes&#39;, database=&#39;u23_2_3&#39;, description=None, tableType=&#39;MANAGED&#39;, isTemporary=False)]
# </div>

# %% [markdown]
# ### create df from catalog table

# %%
flights = spark.table('flights_small')
print('length = ', flights.count())
flights.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">length =  10000
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# 2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA| LAX|     132|     954|   6|    58|
# 2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|
# 2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA| SFO|     111|     679|  14|    43|
# 2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX| SJC|      83|     569|  17|     5|
# 2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA| BUR|     127|     937|   7|    54|
# 2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX| DEN|     121|     991|  10|    37|
# 2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX| OAK|      90|     543|   8|    47|
# 2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA| SFO|      98|     679|  16|    55|
# 2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|  12|    36|
# 2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|  18|    12|
# 2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA| LAX|     130|     954|  16|    53|
# 2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|  11|    20|
# 2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA| LAS|     127|     867|   8|    11|
# 2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|  23|    46|
# 2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA| SFO|     129|     679|  13|    14|
# 2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX| SFO|      90|     550|  20|     9|
# 2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA| SMF|      76|     605|  20|    15|
# 2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA| MDW|     216|    1733|  10|    17|
# 2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA| BOS|     290|    2496|  21|    56|
# 2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX| BUR|     111|     817|  17|    33|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### add column

# %%
flights = flights.withColumn('duration_hrs', flights.air_time / 60)
flights.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|      duration_hrs|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# 2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA| LAX|     132|     954|   6|    58|               2.2|
# 2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|               6.0|
# 2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA| SFO|     111|     679|  14|    43|              1.85|
# 2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX| SJC|      83|     569|  17|     5|1.3833333333333333|
# 2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA| BUR|     127|     937|   7|    54|2.1166666666666667|
# 2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX| DEN|     121|     991|  10|    37|2.0166666666666666|
# 2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX| OAK|      90|     543|   8|    47|               1.5|
# 2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA| SFO|      98|     679|  16|    55|1.6333333333333333|
# 2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|  12|    36|              2.25|
# 2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|  18|    12|               3.3|
# 2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA| LAX|     130|     954|  16|    53|2.1666666666666665|
# 2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|  11|    20| 2.566666666666667|
# 2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA| LAS|     127|     867|   8|    11|2.1166666666666667|
# 2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|  23|    46|              3.05|
# 2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA| SFO|     129|     679|  13|    14|              2.15|
# 2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX| SFO|      90|     550|  20|     9|               1.5|
# 2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA| SMF|      76|     605|  20|    15|1.2666666666666666|
# 2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA| MDW|     216|    1733|  10|    17|               3.6|
# 2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA| BOS|     290|    2496|  21|    56| 4.833333333333333|
# 2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX| BUR|     111|     817|  17|    33|              1.85|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### some SQL queries

# %%
query = "SELECT origin, dest, air_time/60 FROM flights_small"
q1 = spark.sql(query)
q1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+-----------------------------------------------+
# origin|dest|(CAST(air_time AS DOUBLE) / CAST(60 AS DOUBLE))|
# +------+----+-----------------------------------------------+
#    SEA| LAX|                                            2.2|
#    SEA| HNL|                                            6.0|
#    SEA| SFO|                                           1.85|
#    PDX| SJC|                             1.3833333333333333|
#    SEA| BUR|                             2.1166666666666667|
#    PDX| DEN|                             2.0166666666666666|
#    PDX| OAK|                                            1.5|
#    SEA| SFO|                             1.6333333333333333|
#    SEA| SAN|                                           2.25|
#    SEA| ORD|                                            3.3|
#    SEA| LAX|                             2.1666666666666665|
#    SEA| PHX|                              2.566666666666667|
#    SEA| LAS|                             2.1166666666666667|
#    SEA| ANC|                                           3.05|
#    SEA| SFO|                                           2.15|
#    PDX| SFO|                                            1.5|
#    SEA| SMF|                             1.2666666666666666|
#    SEA| MDW|                                            3.6|
#    SEA| BOS|                              4.833333333333333|
#    PDX| BUR|                                           1.85|
# +------+----+-----------------------------------------------+
# only showing top 20 rows
#
# </div>

# %%
query = "SELECT dest, tailnum FROM flights_small WHERE air_time>120"
q2 = spark.sql(query)
q2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-------+
# dest|tailnum|
# +----+-------+
#  LAX| N846VA|
#  HNL| N559AS|
#  BUR| N612AS|
#  DEN| N646SW|
#  SAN| N309AS|
#  ORD| N564AS|
#  LAX| N323AS|
#  PHX| N305AS|
#  LAS| N433AS|
#  ANC| N765AS|
#  SFO| N713AS|
#  MDW| N8634A|
#  BOS| N597AS|
#  PHL| N127UW|
#  OGG| N395HA|
#  LAS| N549AS|
#  LGB| N606JB|
#  SAN| N461AS|
#  ANC| N590JB|
#  LIH| N512AS|
# +----+-------+
# only showing top 20 rows
#
# </div>

# %%
query = "SELECT origin, COUNT(*) FROM flights_small GROUP BY origin"
q3 = spark.sql(query)
q3.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+--------+
# origin|count(1)|
# +------+--------+
#    SEA|    6754|
#    PDX|    3246|
# +------+--------+
#
# </div>

# %%
query = "SELECT origin, dest, COUNT(*) FROM flights_small GROUP BY origin, dest"
q4 = spark.sql(query)
q4.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+--------+
# origin|dest|count(1)|
# +------+----+--------+
#    SEA| RNO|       8|
#    SEA| DTW|      98|
#    SEA| CLE|       2|
#    SEA| LAX|     450|
#    PDX| SEA|     144|
#    SEA| BLI|       5|
#    PDX| IAH|      57|
#    PDX| PHX|     209|
#    SEA| SLC|     225|
#    SEA| SBA|      23|
#    SEA| BWI|      29|
#    PDX| IAD|      23|
#    PDX| SFO|     305|
#    SEA| KOA|      40|
#    PDX| MCI|      15|
#    SEA| SJC|     213|
#    SEA| ABQ|      43|
#    SEA| SAT|      18|
#    PDX| ONT|      57|
#    SEA| LAS|     364|
# +------+----+--------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### dataframe `filter`: example 1

# %%
# pass SQL-like query as string
flights.filter('air_time > 120').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|      duration_hrs|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# 2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA| LAX|     132|     954|   6|    58|               2.2|
# 2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|               6.0|
# 2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA| BUR|     127|     937|   7|    54|2.1166666666666667|
# 2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX| DEN|     121|     991|  10|    37|2.0166666666666666|
# 2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|  12|    36|              2.25|
# 2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|  18|    12|               3.3|
# 2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA| LAX|     130|     954|  16|    53|2.1666666666666665|
# 2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|  11|    20| 2.566666666666667|
# 2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA| LAS|     127|     867|   8|    11|2.1166666666666667|
# 2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|  23|    46|              3.05|
# 2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA| SFO|     129|     679|  13|    14|              2.15|
# 2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA| MDW|     216|    1733|  10|    17|               3.6|
# 2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA| BOS|     290|    2496|  21|    56| 4.833333333333333|
# 2014|    9| 26|     610|       -5|    1523|       65|     US| N127UW|   616|   SEA| PHL|     293|    2378|   6|    10| 4.883333333333334|
# 2014|   12|  4|     954|       -6|    1348|      -17|     HA| N395HA|    29|   SEA| OGG|     333|    2640|   9|    54|              5.55|
# 2014|    2| 25|     555|       -5|     819|       -3|     AS| N549AS|   604|   SEA| LAS|     121|     867|   5|    55|2.0166666666666666|
# 2014|    8| 24|    1646|       21|    1901|        1|     B6| N606JB|  1007|   SEA| LGB|     121|     965|  16|    46|2.0166666666666666|
# 2014|    6|  4|    1115|        0|    1346|       -3|     AS| N461AS|   488|   SEA| SAN|     133|    1050|  11|    15| 2.216666666666667|
# 2014|    6| 26|    2054|       -1|    2318|       -6|     B6| N590JB|   907|   SEA| ANC|     179|    1448|  20|    54|2.9833333333333334|
# 2014|    6|  7|    1823|       -7|    2112|      -28|     AS| N512AS|   815|   SEA| LIH|     335|    2701|  18|    23| 5.583333333333333|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# only showing top 20 rows
#
# </div>

# %%
# pass column of bools
flights.filter(flights.air_time>120).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|      duration_hrs|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# 2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA| LAX|     132|     954|   6|    58|               2.2|
# 2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|               6.0|
# 2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA| BUR|     127|     937|   7|    54|2.1166666666666667|
# 2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX| DEN|     121|     991|  10|    37|2.0166666666666666|
# 2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|  12|    36|              2.25|
# 2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|  18|    12|               3.3|
# 2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA| LAX|     130|     954|  16|    53|2.1666666666666665|
# 2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|  11|    20| 2.566666666666667|
# 2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA| LAS|     127|     867|   8|    11|2.1166666666666667|
# 2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|  23|    46|              3.05|
# 2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA| SFO|     129|     679|  13|    14|              2.15|
# 2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA| MDW|     216|    1733|  10|    17|               3.6|
# 2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA| BOS|     290|    2496|  21|    56| 4.833333333333333|
# 2014|    9| 26|     610|       -5|    1523|       65|     US| N127UW|   616|   SEA| PHL|     293|    2378|   6|    10| 4.883333333333334|
# 2014|   12|  4|     954|       -6|    1348|      -17|     HA| N395HA|    29|   SEA| OGG|     333|    2640|   9|    54|              5.55|
# 2014|    2| 25|     555|       -5|     819|       -3|     AS| N549AS|   604|   SEA| LAS|     121|     867|   5|    55|2.0166666666666666|
# 2014|    8| 24|    1646|       21|    1901|        1|     B6| N606JB|  1007|   SEA| LGB|     121|     965|  16|    46|2.0166666666666666|
# 2014|    6|  4|    1115|        0|    1346|       -3|     AS| N461AS|   488|   SEA| SAN|     133|    1050|  11|    15| 2.216666666666667|
# 2014|    6| 26|    2054|       -1|    2318|       -6|     B6| N590JB|   907|   SEA| ANC|     179|    1448|  20|    54|2.9833333333333334|
# 2014|    6|  7|    1823|       -7|    2112|      -28|     AS| N512AS|   815|   SEA| LIH|     335|    2701|  18|    23| 5.583333333333333|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### dataframe `filter`: example 2

# %%
long_flights1 = flights.filter('distance > 1000')
long_flights1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|      duration_hrs|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# 2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|               6.0|
# 2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|  12|    36|              2.25|
# 2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|  18|    12|               3.3|
# 2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|  11|    20| 2.566666666666667|
# 2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|  23|    46|              3.05|
# 2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA| MDW|     216|    1733|  10|    17|               3.6|
# 2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA| BOS|     290|    2496|  21|    56| 4.833333333333333|
# 2014|    9| 26|     610|       -5|    1523|       65|     US| N127UW|   616|   SEA| PHL|     293|    2378|   6|    10| 4.883333333333334|
# 2014|   12|  4|     954|       -6|    1348|      -17|     HA| N395HA|    29|   SEA| OGG|     333|    2640|   9|    54|              5.55|
# 2014|    6|  4|    1115|        0|    1346|       -3|     AS| N461AS|   488|   SEA| SAN|     133|    1050|  11|    15| 2.216666666666667|
# 2014|    6| 26|    2054|       -1|    2318|       -6|     B6| N590JB|   907|   SEA| ANC|     179|    1448|  20|    54|2.9833333333333334|
# 2014|    6|  7|    1823|       -7|    2112|      -28|     AS| N512AS|   815|   SEA| LIH|     335|    2701|  18|    23| 5.583333333333333|
# 2014|    4| 30|     801|        1|    1757|       90|     AS| N407AS|    18|   SEA| MCO|     342|    2554|   8|     1|               5.7|
# 2014|   11| 29|     905|      155|    1655|      170|     DL| N824DN|  1598|   SEA| ATL|     229|    2182|   9|     5| 3.816666666666667|
# 2014|    6|  2|    2222|        7|      55|       15|     AS| N402AS|    99|   SEA| ANC|     190|    1448|  22|    22|3.1666666666666665|
# 2014|   11| 15|    1034|       -6|    1414|      -26|     AS| N589AS|   794|   SEA| ABQ|     139|    1180|  10|    34| 2.316666666666667|
# 2014|   10| 20|    1328|       -1|    1949|        4|     UA| N68805|  1212|   SEA| IAH|     228|    1874|  13|    28|               3.8|
# 2014|   12| 16|    1500|        0|    1906|       19|     US| N662AW|   500|   SEA| PHX|     151|    1107|  15|     0|2.5166666666666666|
# 2014|   11| 19|    1319|       -6|    1821|      -14|     DL| N309US|  2164|   PDX| MSP|     169|    1426|  13|    19| 2.816666666666667|
# 2014|    5| 21|     515|        0|     757|        0|     US| N172US|   593|   SEA| PHX|     143|    1107|   5|    15|2.3833333333333333|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# only showing top 20 rows
#
# </div>

# %%
long_flights2 = flights.filter(flights.distance>1000)
long_flights2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|      duration_hrs|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# 2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|               6.0|
# 2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|  12|    36|              2.25|
# 2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|  18|    12|               3.3|
# 2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|  11|    20| 2.566666666666667|
# 2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|  23|    46|              3.05|
# 2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA| MDW|     216|    1733|  10|    17|               3.6|
# 2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA| BOS|     290|    2496|  21|    56| 4.833333333333333|
# 2014|    9| 26|     610|       -5|    1523|       65|     US| N127UW|   616|   SEA| PHL|     293|    2378|   6|    10| 4.883333333333334|
# 2014|   12|  4|     954|       -6|    1348|      -17|     HA| N395HA|    29|   SEA| OGG|     333|    2640|   9|    54|              5.55|
# 2014|    6|  4|    1115|        0|    1346|       -3|     AS| N461AS|   488|   SEA| SAN|     133|    1050|  11|    15| 2.216666666666667|
# 2014|    6| 26|    2054|       -1|    2318|       -6|     B6| N590JB|   907|   SEA| ANC|     179|    1448|  20|    54|2.9833333333333334|
# 2014|    6|  7|    1823|       -7|    2112|      -28|     AS| N512AS|   815|   SEA| LIH|     335|    2701|  18|    23| 5.583333333333333|
# 2014|    4| 30|     801|        1|    1757|       90|     AS| N407AS|    18|   SEA| MCO|     342|    2554|   8|     1|               5.7|
# 2014|   11| 29|     905|      155|    1655|      170|     DL| N824DN|  1598|   SEA| ATL|     229|    2182|   9|     5| 3.816666666666667|
# 2014|    6|  2|    2222|        7|      55|       15|     AS| N402AS|    99|   SEA| ANC|     190|    1448|  22|    22|3.1666666666666665|
# 2014|   11| 15|    1034|       -6|    1414|      -26|     AS| N589AS|   794|   SEA| ABQ|     139|    1180|  10|    34| 2.316666666666667|
# 2014|   10| 20|    1328|       -1|    1949|        4|     UA| N68805|  1212|   SEA| IAH|     228|    1874|  13|    28|               3.8|
# 2014|   12| 16|    1500|        0|    1906|       19|     US| N662AW|   500|   SEA| PHX|     151|    1107|  15|     0|2.5166666666666666|
# 2014|   11| 19|    1319|       -6|    1821|      -14|     DL| N309US|  2164|   PDX| MSP|     169|    1426|  13|    19| 2.816666666666667|
# 2014|    5| 21|     515|        0|     757|        0|     US| N172US|   593|   SEA| PHX|     143|    1107|   5|    15|2.3833333333333333|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### dataframe `select` then `filter`

# %%
# pass strings
selected1 = flights.select('tailnum', 'origin', 'dest')
selected1.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------+----+
# tailnum|origin|dest|
# +-------+------+----+
#  N846VA|   SEA| LAX|
#  N559AS|   SEA| HNL|
#  N847VA|   SEA| SFO|
#  N360SW|   PDX| SJC|
#  N612AS|   SEA| BUR|
#  N646SW|   PDX| DEN|
#  N422WN|   PDX| OAK|
#  N361VA|   SEA| SFO|
#  N309AS|   SEA| SAN|
#  N564AS|   SEA| ORD|
#  N323AS|   SEA| LAX|
#  N305AS|   SEA| PHX|
#  N433AS|   SEA| LAS|
#  N765AS|   SEA| ANC|
#  N713AS|   SEA| SFO|
#  N27205|   PDX| SFO|
#  N626AS|   SEA| SMF|
#  N8634A|   SEA| MDW|
#  N597AS|   SEA| BOS|
#  N215AG|   PDX| BUR|
# +-------+------+----+
# only showing top 20 rows
#
# </div>

# %%
# pass column objects
temp = flights.select(flights.origin, flights.dest, flights.carrier)
temp.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+-------+
# origin|dest|carrier|
# +------+----+-------+
#    SEA| LAX|     VX|
#    SEA| HNL|     AS|
#    SEA| SFO|     VX|
#    PDX| SJC|     WN|
#    SEA| BUR|     AS|
#    PDX| DEN|     WN|
#    PDX| OAK|     WN|
#    SEA| SFO|     VX|
#    SEA| SAN|     AS|
#    SEA| ORD|     AS|
#    SEA| LAX|     AS|
#    SEA| PHX|     AS|
#    SEA| LAS|     AS|
#    SEA| ANC|     AS|
#    SEA| SFO|     AS|
#    PDX| SFO|     UA|
#    SEA| SMF|     AS|
#    SEA| MDW|     WN|
#    SEA| BOS|     AS|
#    PDX| BUR|     OO|
# +------+----+-------+
# only showing top 20 rows
#
# </div>

# %%
filterA = flights.origin == 'SEA'
filterB = flights.dest   == 'PDX'
selected2 = temp.filter(filterA).filter(filterB)
selected2.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+-------+
# origin|dest|carrier|
# +------+----+-------+
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     AS|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     AS|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
#    SEA| PDX|     OO|
# +------+----+-------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### dataframe `select` with operations: example 1

# %%
flights.select(flights.air_time / 60).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#    (air_time / 60)|
# +------------------+
#                2.2|
#                6.0|
#               1.85|
# 1.3833333333333333|
# 2.1166666666666667|
# +------------------+
# only showing top 5 rows
#
# </div>

# %%
flights.select((flights.air_time / 60).alias('duration_hrs')).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#       duration_hrs|
# +------------------+
#                2.2|
#                6.0|
#               1.85|
# 1.3833333333333333|
# 2.1166666666666667|
# +------------------+
# only showing top 5 rows
#
# </div>

# %%
flights.selectExpr('air_time/60 as duration_hrs').show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#       duration_hrs|
# +------------------+
#                2.2|
#                6.0|
#               1.85|
# 1.3833333333333333|
# 2.1166666666666667|
# +------------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### dataframe `select` with operations: example 2

# %%
# Define avg_speed
avg_speed = (flights.distance/(flights.air_time/60)).alias("avg_speed")

# Select the correct columns
speed1 = flights.select("origin", "dest", "tailnum", avg_speed)
speed1.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+-------+------------------+
# origin|dest|tailnum|         avg_speed|
# +------+----+-------+------------------+
#    SEA| LAX| N846VA| 433.6363636363636|
#    SEA| HNL| N559AS| 446.1666666666667|
#    SEA| SFO| N847VA|367.02702702702703|
#    PDX| SJC| N360SW| 411.3253012048193|
#    SEA| BUR| N612AS| 442.6771653543307|
# +------+----+-------+------------------+
# only showing top 5 rows
#
# </div>

# %%
# Create the same table using a SQL expression
speed2 = flights.selectExpr("origin", "dest", "tailnum", "distance/(air_time/60) as avg_speed")
speed2.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+----+-------+------------------+
# origin|dest|tailnum|         avg_speed|
# +------+----+-------+------------------+
#    SEA| LAX| N846VA| 433.6363636363636|
#    SEA| HNL| N559AS| 446.1666666666667|
#    SEA| SFO| N847VA|367.02702702702703|
#    PDX| SJC| N360SW| 411.3253012048193|
#    SEA| BUR| N612AS| 442.6771653543307|
# +------+----+-------+------------------+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ### dataframe aggregation
# ##### Find the shortest flight from PDX in terms of distance

# %%
flights.filter(flights.origin=='PDX').groupBy().min('distance').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
# min(distance)|
# +-------------+
#           106|
# +-------------+
#
# </div>

# %% [markdown]
# ##### Find the longest flight from SEA in terms of air time

# %%
# does not work because air_time is string not numeric
#flights.filter(flights.origin=='SEA').groupBy().max('air_time').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
flights = flights.withColumn('air_time_num', flights.air_time.astype('float'))
flights.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+------------+
# year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|      duration_hrs|air_time_num|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+------------+
# 2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA| LAX|     132|     954|   6|    58|               2.2|       132.0|
# 2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|               6.0|       360.0|
# 2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA| SFO|     111|     679|  14|    43|              1.85|       111.0|
# 2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX| SJC|      83|     569|  17|     5|1.3833333333333333|        83.0|
# 2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA| BUR|     127|     937|   7|    54|2.1166666666666667|       127.0|
# 2014|    1| 15|    1037|        7|    1352|        2|     WN| N646SW|    48|   PDX| DEN|     121|     991|  10|    37|2.0166666666666666|       121.0|
# 2014|    7|  2|     847|       42|    1041|       51|     WN| N422WN|  1520|   PDX| OAK|      90|     543|   8|    47|               1.5|        90.0|
# 2014|    5| 12|    1655|       -5|    1842|      -18|     VX| N361VA|   755|   SEA| SFO|      98|     679|  16|    55|1.6333333333333333|        98.0|
# 2014|    4| 19|    1236|       -4|    1508|       -7|     AS| N309AS|   490|   SEA| SAN|     135|    1050|  12|    36|              2.25|       135.0|
# 2014|   11| 19|    1812|       -3|    2352|       -4|     AS| N564AS|    26|   SEA| ORD|     198|    1721|  18|    12|               3.3|       198.0|
# 2014|   11|  8|    1653|       -2|    1924|       -1|     AS| N323AS|   448|   SEA| LAX|     130|     954|  16|    53|2.1666666666666665|       130.0|
# 2014|    8|  3|    1120|        0|    1415|        2|     AS| N305AS|   656|   SEA| PHX|     154|    1107|  11|    20| 2.566666666666667|       154.0|
# 2014|   10| 30|     811|       21|    1038|       29|     AS| N433AS|   608|   SEA| LAS|     127|     867|   8|    11|2.1166666666666667|       127.0|
# 2014|   11| 12|    2346|       -4|     217|      -28|     AS| N765AS|   121|   SEA| ANC|     183|    1448|  23|    46|              3.05|       183.0|
# 2014|   10| 31|    1314|       89|    1544|      111|     AS| N713AS|   306|   SEA| SFO|     129|     679|  13|    14|              2.15|       129.0|
# 2014|    1| 29|    2009|        3|    2159|        9|     UA| N27205|  1458|   PDX| SFO|      90|     550|  20|     9|               1.5|        90.0|
# 2014|   12| 17|    2015|       50|    2150|       41|     AS| N626AS|   368|   SEA| SMF|      76|     605|  20|    15|1.2666666666666666|        76.0|
# 2014|    8| 11|    1017|       -3|    1613|       -7|     WN| N8634A|   827|   SEA| MDW|     216|    1733|  10|    17|               3.6|       216.0|
# 2014|    1| 13|    2156|       -9|     607|      -15|     AS| N597AS|    24|   SEA| BOS|     290|    2496|  21|    56| 4.833333333333333|       290.0|
# 2014|    6|  5|    1733|      -12|    1945|      -10|     OO| N215AG|  3488|   PDX| BUR|     111|     817|  17|    33|              1.85|       111.0|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+------------+
# only showing top 20 rows
#
# </div>

# %%
flights.filter(flights.origin=='SEA').groupBy().max('air_time_num').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
# max(air_time_num)|
# +-----------------+
#             409.0|
# +-----------------+
#
# </div>

# %% [markdown]
# ##### Average duration of Delta flights that left SEA

# %%
flights.filter(flights.origin=='SEA').filter(flights.carrier=='DL').groupBy().avg('air_time_num').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#  avg(air_time_num)|
# +------------------+
# 188.20689655172413|
# +------------------+
#
# </div>

# %% [markdown]
# ##### total hours in air

# %%
flights.withColumn("duration_hrs", flights.air_time/60).groupBy().sum("duration_hrs").show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#  sum(duration_hrs)|
# +------------------+
# 25289.600000000126|
# +------------------+
#
# </div>

# %% [markdown]
# ### dataframe `groupBy`
# ##### total number flights for each plane

# %%
# Group by tailnum
by_plane = flights.groupBy('tailnum')

# Number of flights each plane made
by_plane.count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----+
# tailnum|count|
# +-------+-----+
#  N442AS|   38|
#  N102UW|    2|
#  N36472|    4|
#  N38451|    4|
#  N73283|    4|
#  N513UA|    2|
#  N954WN|    5|
#  N388DA|    3|
#  N567AA|    1|
#  N516UA|    2|
#  N927DN|    1|
#  N8322X|    1|
#  N466SW|    1|
#   N6700|    1|
#  N607AS|   45|
#  N622SW|    4|
#  N584AS|   31|
#  N914WN|    4|
#  N654AW|    2|
#  N336NW|    1|
# +-------+-----+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ##### average duration of flights by origin

# %%
# Group by origin
by_origin = flights.groupBy('origin')

# Average duration of flights from PDX and SEA
by_origin.avg('air_time_num').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------+------------------+
# origin| avg(air_time_num)|
# +------+------------------+
#    SEA| 160.4361496051259|
#    PDX|137.11543248288737|
# +------+------------------+
#
# </div>

# %% [markdown]
# ### dataframe `agg`
# ##### departure delay: avg, std

# %%
import pyspark.sql.functions as F
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
flights = flights.withColumn('dep_delay_num', flights.dep_delay.astype('float'))
flights.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+------------+-------------+
# year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|      duration_hrs|air_time_num|dep_delay_num|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+------------+-------------+
# 2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA| LAX|     132|     954|   6|    58|               2.2|       132.0|         -7.0|
# 2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|               6.0|       360.0|          5.0|
# 2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA| SFO|     111|     679|  14|    43|              1.85|       111.0|         -2.0|
# 2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX| SJC|      83|     569|  17|     5|1.3833333333333333|        83.0|         45.0|
# 2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA| BUR|     127|     937|   7|    54|2.1166666666666667|       127.0|         -1.0|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+------------+-------------+
# only showing top 5 rows
#
# </div>

# %%
# Group by month and dest
by_month_dest = flights.groupBy('month', 'dest')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Average departure delay by month and destination
by_month_dest.avg('dep_delay_num').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----+-------------------+
# month|dest| avg(dep_delay_num)|
# +-----+----+-------------------+
#     4| PHX| 1.6833333333333333|
#     1| RDM|             -1.625|
#     5| ONT| 3.5555555555555554|
#     7| OMA|               -6.5|
#     8| MDW|               7.45|
#     6| DEN|  5.418181818181818|
#     5| IAD|               -4.0|
#    12| COS|               -1.0|
#    11| ANC|  7.529411764705882|
#     5| AUS|              -0.75|
#     5| COS| 11.666666666666666|
#     2| PSP|                0.6|
#     4| ORD|0.14285714285714285|
#    10| DFW| 18.176470588235293|
#    10| DCA|               -1.5|
#     8| JNU|             18.125|
#    11| KOA|               -1.0|
#    10| OMA|-0.6666666666666666|
#     6| ONT|              9.625|
#     3| MSP|                3.2|
# +-----+----+-------------------+
# only showing top 20 rows
#
# </div>

# %%
# Standard deviation of departure delay
by_month_dest.agg(F.stddev('dep_delay_num')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----+--------------------------+
# month|dest|stddev_samp(dep_delay_num)|
# +-----+----+--------------------------+
#     4| PHX|        15.003380033491737|
#     1| RDM|         8.830749846821778|
#     5| ONT|        18.895178691342874|
#     7| OMA|        2.1213203435596424|
#     8| MDW|        14.467659032985843|
#     6| DEN|        13.536905534420026|
#     5| IAD|        3.8078865529319543|
#    12| COS|        1.4142135623730951|
#    11| ANC|        18.604716401245316|
#     5| AUS|         4.031128874149275|
#     5| COS|         33.38163167571851|
#     2| PSP|         4.878524367060187|
#     4| ORD|        11.593882803741764|
#    10| DFW|         45.53019017606675|
#    10| DCA|        0.7071067811865476|
#     8| JNU|         40.79368823727514|
#    11| KOA|        1.8708286933869707|
#    10| OMA|        5.8594652770823155|
#     6| ONT|         25.98316762829351|
#     3| MSP|        21.556779370817555|
# +-----+----+--------------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ### dataframe `join`
# ##### create dataframe from airports table

# %%
airports = spark.table('airports')
print('length = ', airports.count())
airports.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">length =  1397
# +---+--------------------+----------------+-----------------+----+---+---+
# faa|                name|             lat|              lon| alt| tz|dst|
# +---+--------------------+----------------+-----------------+----+---+---+
# 04G|   Lansdowne Airport|      41.1304722|      -80.6195833|1044| -5|  A|
# 06A|Moton Field Munic...|      32.4605722|      -85.6800278| 264| -5|  A|
# 06C| Schaumburg Regional|      41.9893408|      -88.1012428| 801| -6|  A|
# 06N|     Randall Airport|       41.431912|      -74.3915611| 523| -5|  A|
# 09J|Jekyll Island Air...|      31.0744722|      -81.4277778|  11| -4|  A|
# 0A9|Elizabethton Muni...|      36.3712222|      -82.1734167|1593| -4|  A|
# 0G6|Williams County A...|      41.4673056|      -84.5067778| 730| -5|  A|
# 0G7|Finger Lakes Regi...|      42.8835647|      -76.7812318| 492| -5|  A|
# 0P2|Shoestring Aviati...|      39.7948244|      -76.6471914|1000| -5|  U|
# 0S9|Jefferson County ...|      48.0538086|     -122.8106436| 108| -8|  A|
# 0W3|Harford County Ai...|      39.5668378|      -76.2024028| 409| -5|  A|
# 10C|  Galt Field Airport|      42.4028889|      -88.3751111| 875| -6|  U|
# 17G|Port Bucyrus-Craw...|      40.7815556|      -82.9748056|1003| -5|  A|
# 19A|Jackson County Ai...|      34.1758638|      -83.5615972| 951| -4|  U|
# 1A3|Martin Campbell F...|      35.0158056|      -84.3468333|1789| -4|  A|
# 1B9| Mansfield Municipal|      42.0001331|      -71.1967714| 122| -5|  A|
# 1C9|Frazier Lake Airpark|54.0133333333333|-124.768333333333| 152| -8|  A|
# 1CS|Clow Internationa...|      41.6959744|      -88.1292306| 670| -6|  U|
# 1G3|  Kent State Airport|      41.1513889|      -81.4151111|1134| -4|  A|
# 1OH|     Fortman Airport|      40.5553253|      -84.3866186| 885| -5|  U|
# +---+--------------------+----------------+-----------------+----+---+---+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# ##### examine dataframes

# %%
flights.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+------------+-------------+
# year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|dest|air_time|distance|hour|minute|      duration_hrs|air_time_num|dep_delay_num|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+------------+-------------+
# 2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA| LAX|     132|     954|   6|    58|               2.2|       132.0|         -7.0|
# 2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA| HNL|     360|    2677|  10|    40|               6.0|       360.0|          5.0|
# 2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA| SFO|     111|     679|  14|    43|              1.85|       111.0|         -2.0|
# 2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX| SJC|      83|     569|  17|     5|1.3833333333333333|        83.0|         45.0|
# 2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA| BUR|     127|     937|   7|    54|2.1166666666666667|       127.0|         -1.0|
# +----+-----+---+--------+---------+--------+---------+-------+-------+------+------+----+--------+--------+----+------+------------------+------------+-------------+
# only showing top 5 rows
#
# </div>

# %%
airports.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+--------------------+----------+-----------+----+---+---+
# faa|                name|       lat|        lon| alt| tz|dst|
# +---+--------------------+----------+-----------+----+---+---+
# 04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|
# 06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|
# 06C| Schaumburg Regional|41.9893408|-88.1012428| 801| -6|  A|
# 06N|     Randall Airport| 41.431912|-74.3915611| 523| -5|  A|
# 09J|Jekyll Island Air...|31.0744722|-81.4277778|  11| -4|  A|
# +---+--------------------+----------+-----------+----+---+---+
# only showing top 5 rows
#
# </div>

# %%
airports.filter((airports.faa=='SEA') | (airports.faa=='PDX')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-------------------+---------+-----------+---+---+---+
# faa|               name|      lat|        lon|alt| tz|dst|
# +---+-------------------+---------+-----------+---+---+---+
# PDX|      Portland Intl|45.588722|  -122.5975| 30| -8|  A|
# SEA|Seattle Tacoma Intl|   47.449|-122.309306|433| -8|  A|
# +---+-------------------+---------+-----------+---+---+---+
#
# </div>

# %% [markdown]
# ##### rename column in airports df

# %%
airports = airports.withColumnRenamed('faa', 'dest')
airports.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+--------------------+----------+-----------+----+---+---+
# dest|                name|       lat|        lon| alt| tz|dst|
# +----+--------------------+----------+-----------+----+---+---+
#  04G|   Lansdowne Airport|41.1304722|-80.6195833|1044| -5|  A|
#  06A|Moton Field Munic...|32.4605722|-85.6800278| 264| -5|  A|
#  06C| Schaumburg Regional|41.9893408|-88.1012428| 801| -6|  A|
#  06N|     Randall Airport| 41.431912|-74.3915611| 523| -5|  A|
#  09J|Jekyll Island Air...|31.0744722|-81.4277778|  11| -4|  A|
# +----+--------------------+----------+-----------+----+---+---+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ##### `join`

# %%
flights_with_airports = flights.join(airports, on='dest', how='leftouter')
flights_with_airports.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+--------+--------+----+------+------------------+------------+-------------+--------------------+---------+-----------+---+---+---+
# dest|year|month|day|dep_time|dep_delay|arr_time|arr_delay|carrier|tailnum|flight|origin|air_time|distance|hour|minute|      duration_hrs|air_time_num|dep_delay_num|                name|      lat|        lon|alt| tz|dst|
# +----+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+--------+--------+----+------+------------------+------------+-------------+--------------------+---------+-----------+---+---+---+
#  LAX|2014|   12|  8|     658|       -7|     935|       -5|     VX| N846VA|  1780|   SEA|     132|     954|   6|    58|               2.2|       132.0|         -7.0|    Los Angeles Intl|33.942536|-118.408075|126| -8|  A|
#  HNL|2014|    1| 22|    1040|        5|    1505|        5|     AS| N559AS|   851|   SEA|     360|    2677|  10|    40|               6.0|       360.0|          5.0|       Honolulu Intl|21.318681|-157.922428| 13|-10|  N|
#  SFO|2014|    3|  9|    1443|       -2|    1652|        2|     VX| N847VA|   755|   SEA|     111|     679|  14|    43|              1.85|       111.0|         -2.0|  San Francisco Intl|37.618972|-122.374889| 13| -8|  A|
#  SJC|2014|    4|  9|    1705|       45|    1839|       34|     WN| N360SW|   344|   PDX|      83|     569|  17|     5|1.3833333333333333|        83.0|         45.0|Norman Y Mineta S...|  37.3626|-121.929022| 62| -8|  A|
#  BUR|2014|    3|  9|     754|       -1|    1015|        1|     AS| N612AS|   522|   SEA|     127|     937|   7|    54|2.1166666666666667|       127.0|         -1.0|            Bob Hope|34.200667|-118.358667|778| -8|  A|
# +----+----+-----+---+--------+---------+--------+---------+-------+-------+------+------+--------+--------+----+------+------------------+------------+-------------+--------------------+---------+-----------+---+---+---+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# ##### check df lengths

# %%
print('length flights  = ', flights.count())
print('length airports = ', airports.count())
print('length flights_with_airports = ', flights_with_airports.count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">length flights  =  10000
# length airports =  1397
# length flights_with_airports =  10000
# </div>
